# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# random numbers
import random # bring in random tools
# get random number between 1 and 10 (inclusive)
random.randint(1, 10)

import math
math.sqrt(25)
# Out:
# 5.0

# %%
# simple function
def write_hello():
    print("Hello!")

write_hello()
# Out:
# Hello!

# %%
# function with a parameter
def greeting(phrase, name):
    print(f"{phrase}, {name}")

greeting("Hello", "John")
greeting("Aloha", "Jill")

# print(phrase) - phrase doesn't exist outside of function
# Out:
# Hello, John
# Aloha, Jill

# %%
# global variables
name = "John"

def greeting(name):
    # modify the parameter to a new value
    name = "Jack"
    # the name parameter is a local variable
    print(f"Gutentag, {name}")

print(f"Hello, {name}")
greeting("Jane")
# Out:
# Hello, John
# Gutentag, Jack

# %%
# high / low game
import random

levels = [
    {'min': 1, 'max': 10, 'tries': 3},
    {'min': 1, 'max': 100, 'tries': 5},
    {'min': 1, 'max': 1000, 'tries': 10}
]

def generate_answer(level):
    # generate a random number between min - max
    answer = random.randint(level['min'], level['max'])
    print(answer)
    return answer

def take_a_guess():
    # ask user to make a guess
    guess = int(input("Guess a number: "))
    return guess

def check_answer(answer, guess):
    if answer < guess:
        print("Too High")
        return False
    elif answer > guess:
        print("Too Low")
        return False
    else:
        return True
    
def check_for_winner(win):
    if win:
        print("You WIN!")
    else:
        print("You LOSE!")

def game_loop(answer, allowed_guesses):
    num_guesses = 0
    while num_guesses < allowed_guesses:
        guess = take_a_guess()
        win = check_answer(answer, guess)
        if win:
            break
        num_guesses += 1
    return [guess, win]

def high_low_game():
    allowed_guesses = 3
    current_level = 1
    choice = 'Y'
    while current_level <= 3 and choice == 'Y':
        print(f"Level: {current_level}")
        print(f"Range: {levels[current_level - 1]['min']} to {levels[current_level - 1]['max']}")
        answer = generate_answer(levels[current_level - 1])
        guess, win = game_loop(answer, allowed_guesses)
        check_for_winner(win)
        # check to see if user wants next level on win
        choice = 'N'
        if win:
            if current_level < 3:
                choice = input("Do you want to continue? (Y/N) ")
                if choice == 'Y':
                    current_level += 1
            else:
                print("Achievement Unlocked! MASTER LEVEL!")

# start game
high_low_game()
# Out:
# Level: 1
# Range: 1 to 10
# 7
# You WIN!
# Level: 2
# Range: 1 to 100
# 42
# You WIN!
# Level: 3
# Range: 1 to 1000
# 633
# You WIN!
# Achievement Unlocked! MASTER LEVEL!

# %%
# pass by value

def pass_by_value(integer, decimal, boolean, string):
    integer += 1
    decimal *= 37.32
    boolean = not boolean
    string = "a different string"
    print(f"inside: i = {integer}, d = {decimal}, b = {boolean}, s = {string}")

i = 10
d = 1.0
b = False
s = "a string"
print(f"before: i = {i}, d = {d}, b = {b}, s = {s}")
pass_by_value(i, d, b, s)
print(f"after: i = {i}, d = {d}, b = {b}, s = {s}")
# Out:
# before: i = 10, d = 1.0, b = False, s = a string
# inside: i = 11, d = 37.32, b = True, s = a different string
# after: i = 10, d = 1.0, b = False, s = a string

# %%
# pass by reference
def pass_by_reference(my_list, my_dict):
    my_list[0] = 234
    my_list.append(999)
    my_dict['orange'] = 'orange'
    my_list = [6, 7, 8, 9, 10]
    print(f"inside: l = {my_list}, d = {my_dict}")

l = [1, 2, 3, 4, 5]
d = {'apple': 'red', 'banana': 'yellow'}
print(f"before: l = {l}, d = {d}")
pass_by_reference(l, d)
print(f"after: l = {l}, d = {d}")
# Out:
# before: l = [1, 2, 3, 4, 5], d = {'apple': 'red', 'banana': 'yellow'}
# inside: l = [6, 7, 8, 9, 10], d = {'apple': 'red', 'banana': 'yellow', 'orange': 'orange'}
# after: l = [234, 2, 3, 4, 5, 999], d = {'apple': 'red', 'banana': 'yellow', 'orange': 'orange'}

# %%
# unpacking a dictionary

def write_student_info(name, student_id, address):
    print(f"Name = {name}, Student ID = {student_id}")


student = {'name': 'John Smith', 'student_id': 'W123456', 'address': '123 Somewhere Rd'}
write_student_info(student['name'], student['student_id'], student['address'])
write_student_info(**student)
# Out:
# Name = John Smith, Student ID = W123456
# Name = John Smith, Student ID = W123456

# %%
# lambda functions

square = lambda x: x ** 2
# same as below
# def square(x):
#    return x ** 2
print(square(5))

add = lambda a, b: a + b
print(add(1, 2))

hello = lambda t: f"Hello, {t}!"
print(hello("John"))
# Out:
# 25
# 3
# Hello, John!

# %%
# returning multiple values

def get_math_answers(a, b):
    sum = a + b
    diff = a - b
    prod = a * b
    quot = a / b
    return [sum, diff, prod, quot]

s, d, p, q = get_math_answers(1, 2)
print(f"sum = {s}")
# Out:
# sum = 3

# %%
top_ten_scores = []

def add_to_top_ten(score):
    global top_ten_scores
    top_ten_scores = [score]

print(f"before: {top_ten_scores}")
add_to_top_ten(57)
print(f"after: {top_ten_scores}")
# Out:
# before: []
# after: []
